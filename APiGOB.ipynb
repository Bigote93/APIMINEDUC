# %% [markdown]
# <a href="https://colab.research.google.com/github/Bigote93/APIMINEDUC/blob/main/APiGOB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tratamiento de objetivos
#
# * [ x ] Unidad
# * [ x ] Nivel
# * [ x ] Asignatura
# * [ ] Objetivo
# * [ ] Pais
# * [ ] Region
# * [ ] Comuna
# * [ ] Contenido
# *

# %% [markdown]
# ## 1. Apertura de recursos de Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import uuid

# Rutas

objetivos_basica = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/OBJETIVOS_BASICA.xlsx'

objetivos_insert_basica = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/API_OBJ_BASICA_inserts.xlsx'
objetivos_insert_media = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/API_OBJ_MEDIA_inserts.xlsx'

# %% [markdown]
# ## 2. Recursos y diccionarios

# %%
DF_OBJETIVOS = pd.read_excel(objetivos_basica)
OBJETIVOS = DF_OBJETIVOS['descObjetivo']
ASIGNATURAS = DF_OBJETIVOS['nombreAsignatura'].unique()
NIVELES = DF_OBJETIVOS['nombreNivel'].unique()
UNIDADES = DF_OBJETIVOS['nombreUnidad'].unique()

# %% [markdown]
# ## 3. Asignar UUIID4 unico a cada asignatura

# %%
ASIGNATURAS_ARRAY = []
for asignatura in ASIGNATURAS:
  ASIGNATURAS_ARRAY.append([asignatura,str(uuid.uuid4())])

ASIGNATURAS_DF = pd.DataFrame(ASIGNATURAS_ARRAY,columns=['nombre','idAsignatura'])
ASIGNATURAS_DF.rename(columns = {'nombre': 'nombreAsignatura'}, inplace=True)
ASIGNATURAS_DF
# Out:
#   nombreAsignatura                          idAsignatura
# 0       Matemática  41803da9-da58-4671-8fda-d4474325ea71

# %% [markdown]
# ## 4. Asignar UUIID4 unico a cada nivel

# %%
NIVELES_ARRAY = []
for nivel in NIVELES:
  NIVELES_ARRAY.append([nivel,str(uuid.uuid4())])

NIVELES_DF = pd.DataFrame(NIVELES_ARRAY,columns=['nombre','idNivel'])
NIVELES_DF.rename(columns = {'nombre': 'nombreNivel'}, inplace=True)
NIVELES_DF
# Out:
#        nombreNivel                               idNivel
# 0   Primero Básico  b768a446-fb57-40e2-bf1e-7c169f2b7f88
# 1  Segundo Básico   c499a4a0-4ff1-413c-98ff-5630127eb467
# 2   Tercero Básico  53dfd494-6b93-4a47-932c-e0905166c0f9
# 3    Cuarto Básico  dc7a9505-183a-4951-95fa-a96e02a4c71f
# 4    Quinto Básico  e9de96b2-852d-4941-b744-43de5517d7f6
# 5     Sexto Básico  15edb604-a091-4457-b678-41f45c89d66f
# 6   Septimo Básico  6ac04b5a-3844-4bcb-b5e6-40718994fda4
# 7    Octavo Básico  d6847e5b-3cdd-4ab1-b6c6-335eb0b6c448

# %% [markdown]
# ## 5. Asignar UUIID4 a cada unidad

# %%
UNIDAD_ARRAY = []
for unidad in UNIDADES:
  UNIDAD_ARRAY.append([unidad,str(uuid.uuid4())])

UNIDADES_DF = pd.DataFrame(UNIDAD_ARRAY,columns=['nombre','idUnidad'])
UNIDADES_DF['idAsignatura'] = ASIGNATURAS_DF[ASIGNATURAS_DF['nombreAsignatura'] == 'Matemática'].iloc[0, 1]
UNIDADES_DF.rename(columns = {'nombre': 'nombreUnidad'}, inplace=True)
UNIDADES_DF
# Out:
#                   nombreUnidad                              idUnidad  \
# 0        Números y Operaciones  9db56289-9f7c-4ab7-93bb-21bcb9c25901
# 1           Patrones y Álgebra  44def628-2bd3-4dfc-9ade-0bac964a4a1b
# 2                   Geometría   3e0f6a82-5a5b-4982-8ddc-1add670ee581
# 3                    Medición   25a87490-ccb1-4ee5-b800-f34c38ac3eda
# 4         Datos y probabilidad  7d411c58-ff30-493c-9f03-5760c9c1c6fa
# 5                    Geometría  4c89b542-9dfa-4af8-a344-e67b422f84f8
# 6                     Medición  63260ccb-bd58-4354-a701-b8f6831fa0d8
# 7                      Números  f1dc670f-07c4-4455-a93e-a34bb5c9bac7
# 8          Álgebra y Funciones  b9754764-83d6-4dc1-8d41-abdc2643ff77
# 9  Probabilidad y Estadística   91dd4b3a-50e4-40db-a9e1-f158ac73aa6f
#
#                            idAsignatura
# 0  41803da9-da58-4671-8fda-d4474325ea71
# 1  41803da9-da58-4671-8fda-d4474325ea71
# 2  41803da9-da58-4671-8fda-d4474325ea71
# 3  41803da9-da58-4671-8fda-d4474325ea71
# 4  41803da9-da58-4671-8fda-d4474325ea71
# 5  41803da9-da58-4671-8fda-d4474325ea71
# 6  41803da9-da58-4671-8fda-d4474325ea71
# 7  41803da9-da58-4671-8fda-d4474325ea71
# 8  41803da9-da58-4671-8fda-d4474325ea71
# 9  41803da9-da58-4671-8fda-d4474325ea71

# %% [markdown]
# ## 6. Asignar UUIID4 a cada objetivo

# %%
OBJETIVO_ARRAY = []
for objetivo in OBJETIVOS:
  OBJETIVO_ARRAY.append([objetivo,str(uuid.uuid4())])

OBJETIVOS_DF = pd.DataFrame(OBJETIVO_ARRAY,columns=['nombre','idObjetivo'])
OBJETIVOS_DF.rename(columns = {'nombre': 'descObjetivo'}, inplace=True)
OBJETIVOS_DF
# Out:
#                                           descObjetivo  \
# 0    Contar numeros del 0 al 100 de 1 en 1, de 2 en...
# 1    Identificar el orden de los elementos de una s...
# 2    Leer números del 0 al 20 y representarlos en f...
# 3    Comparar y ordenar números del 0 al 20 de meno...
# 4    Estimar cantidades hasta 20 en situaciones con...
# ..                                                 ...
# 177  Describir la posición y el movimiento (traslac...
# 178  Componer rotaciones, traslaciones y reflexione...
# 179  Mostrar que comprenden las medidas de posición...
# 180  Evaluar la forma en que los datos están presen...
# 181  Explicar el principio combinatorio multiplicat...
#
#                                idObjetivo
# 0    ed69dead-eeb3-49e2-9f65-ccd4215b177a
# 1    27dfc566-f13e-4e70-8402-5d9948ac1f7f
# 2    909ed1d7-b888-4414-87e8-0d8f6413c623
# 3    605bbc35-a146-4122-b2e7-30df03db3a3d
# 4    9d29205f-6187-45c5-bac4-33ebb49cd091
# ..                                    ...
# 177  6b0039d7-10ec-4dd1-963a-28f4ea539207
# 178  94799447-c13d-4fa7-a856-49e21d82ac80
# 179  66c97658-0797-44b9-9081-9d5ae23c6b9e
# 180  6f37eeee-d6c0-4d87-a911-b18db4d53748
# 181  8c73abdc-4e42-4b49-b160-14c0feefd0a2
#
# [182 rows x 2 columns]

# %% [markdown]
# ## Unificar columnas

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(NIVELES_DF[['nombreNivel','idNivel']], how='inner', left_on='nombreNivel', right_on='nombreNivel')
DF_OBJETIVOS.sample(2)
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 141    Sexto Básico  Estudiantes de 11 a 12 años       Matemática
# 8    Primero Básico    Estudiantes de 6 a 7 años       Matemática
#
#               nombreUnidad                                       descObjetivo  \
# 141               Medición  Estimar y medir ángulos usando el transportado...
# 8    Números y Operaciones  Demostrar que comprenden la adición y la sustr...
#
#      insert                               idNivel
# 141     NaN  15edb604-a091-4457-b678-41f45c89d66f
# 8       NaN  b768a446-fb57-40e2-bf1e-7c169f2b7f88

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(OBJETIVOS_DF, how='inner', on='descObjetivo')

DF_OBJETIVOS.sample(2)
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 136    Sexto Básico  Estudiantes de 11 a 12 años       Matemática
# 56   Tercero Básico    Estudiantes de 8 a 9 años       Matemática
#
#     nombreUnidad                                       descObjetivo  insert  \
# 136    Geometría  Construir ángulos agudos, obtusos, rectos, ext...     NaN
# 56     Geometría  Demostrar que comprenden la relación que exist...     NaN
#
#                                   idNivel  \
# 136  15edb604-a091-4457-b678-41f45c89d66f
# 56   53dfd494-6b93-4a47-932c-e0905166c0f9
#
#                                idObjetivo
# 136  4b868c92-f5c4-4df8-b82b-35dbc94aa8a4
# 56   367fe40c-8113-4594-b62f-3c0c034e095c

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(UNIDADES_DF[['nombreUnidad','idUnidad']], how='inner', on='nombreUnidad')

DF_OBJETIVOS
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 0    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 1    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 2    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 3    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 4    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# ..              ...                          ...              ...
# 177  Septimo Básico  Estudiantes de 12 a 13 años       Matemática
# 178  Septimo Básico  Estudiantes de 12 a 13 años       Matemática
# 179   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
# 180   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
# 181   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
#
#                     nombreUnidad  \
# 0          Números y Operaciones
# 1          Números y Operaciones
# 2          Números y Operaciones
# 3          Números y Operaciones
# 4          Números y Operaciones
# ..                           ...
# 177  Probabilidad y Estadística
# 178  Probabilidad y Estadística
# 179  Probabilidad y Estadística
# 180  Probabilidad y Estadística
# 181  Probabilidad y Estadística
#
#                                           descObjetivo  insert  \
# 0    Contar numeros del 0 al 100 de 1 en 1, de 2 en...     NaN
# 1    Identificar el orden de los elementos de una s...     NaN
# 2    Leer números del 0 al 20 y representarlos en f...     NaN
# 3    Comparar y ordenar números del 0 al 20 de meno...     NaN
# 4    Estimar cantidades hasta 20 en situaciones con...     NaN
# ..                                                 ...     ...
# 177  Explicar las probabilidades de eventos obtenid...     NaN
# 178  Comparar las frecuencias relativas de un event...     NaN
# 179  Mostrar que comprenden las medidas de posición...     NaN
# 180  Evaluar la forma en que los datos están presen...     NaN
# 181  Explicar el principio combinatorio multiplicat...     NaN
#
#                                   idNivel  \
# 0    b768a446-fb57-40e2-bf1e-7c169f2b7f88
# 1    b768a446-fb57-40e2-bf1e-7c169f2b7f88
# 2    b768a446-fb57-40e2-bf1e-7c169f2b7f88
# 3    b768a446-fb57-40e2-bf1e-7c169f2b7f88
# 4    b768a446-fb57-40e2-bf1e-7c169f2b7f88
# ..                                    ...
# 177  6ac04b5a-3844-4bcb-b5e6-40718994fda4
# 178  6ac04b5a-3844-4bcb-b5e6-40718994fda4
# 179  d6847e5b-3cdd-4ab1-b6c6-335eb0b6c448
# 180  d6847e5b-3cdd-4ab1-b6c6-335eb0b6c448
# 181  d6847e5b-3cdd-4ab1-b6c6-335eb0b6c448
#
#                                idObjetivo  \
# 0    ed69dead-eeb3-49e2-9f65-ccd4215b177a
# 1    27dfc566-f13e-4e70-8402-5d9948ac1f7f
# 2    909ed1d7-b888-4414-87e8-0d8f6413c623
# 3    605bbc35-a146-4122-b2e7-30df03db3a3d
# 4    9d29205f-6187-45c5-bac4-33ebb49cd091
# ..                                    ...
# 177  f6bf2524-d8ca-4f11-8d77-06e3dc883d01
# 178  1ea943ca-119c-4423-9946-3862e10aaa96
# 179  66c97658-0797-44b9-9081-9d5ae23c6b9e
# 180  6f37eeee-d6c0-4d87-a911-b18db4d53748
# 181  8c73abdc-4e42-4b49-b160-14c0feefd0a2
#
#                                  idUnidad
# 0    9db56289-9f7c-4ab7-93bb-21bcb9c25901
# 1    9db56289-9f7c-4ab7-93bb-21bcb9c25901
# 2    9db56289-9f7c-4ab7-93bb-21bcb9c25901
# 3    9db56289-9f7c-4ab7-93bb-21bcb9c25901
# 4    9db56289-9f7c-4ab7-93bb-21bcb9c25901
# ..                                    ...
# 177  91dd4b3a-50e4-40db-a9e1-f158ac73aa6f
# 178  91dd4b3a-50e4-40db-a9e1-f158ac73aa6f
# 179  91dd4b3a-50e4-40db-a9e1-f158ac73aa6f
# 180  91dd4b3a-50e4-40db-a9e1-f158ac73aa6f
# 181  91dd4b3a-50e4-40db-a9e1-f158ac73aa6f
#
# [182 rows x 9 columns]

# %% [markdown]
# ## Cargar y transformar a excel el json
#
# Para poder almacenar regiones en la base de datos

# %%
import pandas as pd

# Definir la lista de regiones
regiones = [
            {
                'number': 'CHI-1',
                'name': "Región de Arica y Parinacota",
                'comunas': ["Arica", "Camarones", "Putre", "General Lagos"]
            },
            {
                'number': 'CHI-2',
                'name': "Región de Tarapacá",
                'comunas': ["Iquique", "Alto Hospicio", "Pozo Almonte", "Camiña", "Colchane", "Huara", "Pica"],
            },
            {
                'number': 'CHI-3',
                'name': "Región de Antofagasta",
                'comunas': ["Antofagasta", "Mejillones", "Sierra Gorda", "Taltal", "Calama", "Ollagüe", "San Pedro de Atacama", "Tocopilla", "María Elena"],
            },
            {
                'number': 'CHI-4',
                'name': "Región de Atacama",
                'comunas': ["Copiapó", "Caldera", "Tierra Amarilla", "Chañaral", "Diego de Almagro", "Vallenar", "Alto del Carmen", "Freirina", "Huasco"],
            },
            {
                'number': 'CHI-5',
                'name': "Región de Coquimbo",
                'comunas': ["La Serena", "Coquimbo", "Andacollo", "La Higuera", "Paiguano", "Vicuña", "Illapel", "Canela", "Los Vilos", "Salamanca"],
            },
            {
                'number': 'CHI-6',
                'name': "Región de Valparaíso",
                'comunas': ["Valparaíso", "Casablanca", "Concón", "Juan Fernández", "Puchuncaví", "Quintero", "Viña del Mar", "Isla de Pascua", "Los Andes", "Calle Larga", "Rinconada", "San Esteban", "La Ligua", "Cabildo", "Papudo", "Petorca", "Zapallar", "Quillota", "La Calera", "Hijuelas", "La Cruz", "Nogales", "San Antonio", "Algarrobo", "Cartagena", "El Quisco", "El Tabo", "Santo Domingo", "San Felipe", "Catemu", "Llaillay", "Panquehue", "Putaendo", "Santa María", "Quilpué", "Limache", "Olmué"]
            },
            {
                'number': 'CHI-7',
                'name': "Región Metropolitana de Santiago",
                'comunas': ["Santiago", "Cerrillos", "Cerro Navia", "Conchalí", "El Bosque", "Estación Central", "Huechuraba", "Independencia", "La Cisterna", "La Florida", "La Granja", "La Pintana", "La Reina", "Las Condes", "Lo Barnechea", "Lo Espejo", "Lo Prado", "Macul", "Maipú", "Ñuñoa", "Pedro Aguirre Cerda", "Peñalolén", "Providencia", "Pudahuel", "Quilicura", "Quinta Normal", "Recoleta", "Renca", "San Joaquín", "San Miguel", "San Ramón", "Vitacura"]
            },
            {
                'number': 'CHI-8',
                'name': "Región del Libertador General Bernardo O'Higgins",
                'comunas': ["Rancagua", "Codegua", "Coinco", "Coltauco", "Doñihue", "Graneros", "Las Cabras", "Machalí", "Malloa", "Mostazal", "Olivar", "Peumo", "Pichidegua", "Quinta de Tilcoco", "Rengo", "Requínoa", "San Vicente", "Pichilemu", "La Estrella", "Litueche", "Marchihue", "Navidad", "Paredones"]
            },
            {
                'number': 'CHI-9',
                'name': "Región del Maule",
                'comunas': ["Talca", "Constitución", "Curepto", "Empedrado", "Maule", "Pelarco", "Pencahue", "Río Claro", "San Clemente", "San Rafael", "Cauquenes", "Chanco", "Pelluhue", "Curicó", "Hualañé", "Licantén", "Molina", "Rauco", "Romeral", "Sagrada Familia", "Teno", "Vichuquén", "Linares", "Colbún", "Longaví", "Parral", "Retiro", "San Javier", "Villa Alegre", "Yerbas Buenas"]
            },
            {
                'number': 'CHI-10',
                'name': "Región del Maule",
                'comunas': ["Talca", "Constitución", "Curepto", "Empedrado", "Maule", "Pelarco", "Pencahue", "Río Claro", "San Clemente", "San Rafael", "Cauquenes", "Chanco", "Pelluhue", "Curicó", "Hualañé", "Licantén", "Molina", "Rauco", "Romeral", "Sagrada Familia", "Teno", "Vichuquén", "Linares", "Colbún", "Longaví", "Parral", "Retiro", "San Javier", "Villa Alegre", "Yerbas Buenas"]
            },
            {
                'number': 'CHI-11',
                'name': "Región de Ñuble",
                'comunas': ["Chillán", "Chillán Viejo", "Bulnes", "Cobquecura", "Coelemu", "Coihueco", "Chillán Viejo", "El Carmen", "Ninhue", "Ñiquén", "Pemuco", "Pinto", "Portezuelo", "Quillón", "Quirihue", "Ránquil", "San Carlos", "San Fabián", "San Ignacio", "San Nicolás", "Treguaco", "Yungay"]
            },
            {
                'number': 'CHI-12',
                'name': "Región del Biobío",
                'comunas': ["Concepción", "Coronel", "Chiguayante", "Florida", "Hualqui", "Lota", "Penco", "San Pedro de la Paz", "Santa Juana", "Talcahuano", "Tomé", "Hualpén", "Lebu", "Arauco", "Cañete", "Contulmo", "Curanilahue", "Los Álamos", "Tirúa", "Los Ángeles", "Antuco", "Cabrero", "Laja", "Mulchén", "Nacimiento", "Negrete", "Quilaco", "Quilleco", "San Rosendo", "Santa Bárbara", "Tucapel", "Yumbel"]
            },
            {
                'number': 'CHI-13',
                'name': "Región de La Araucanía",
                'comunas': ["Temuco", "Carahue", "Cunco", "Curarrehue", "Freire", "Galvarino", "Gorbea", "Lautaro", "Loncoche", "Melipeuco", "Nueva Imperial", "Padre las Casas", "Perquenco", "Pitrufquén", "Pucón", "Saavedra", "Teodoro Schmidt", "Toltén", "Vilcún", "Villarrica", "Cholchol", "Angol", "Collipulli", "Curacautín", "Ercilla", "Lonquimay", "Los Sauces", "Lumaco", "Purén", "Renaico", "Traiguén", "Victoria"]
            },
            {
                'number': 'CHI-14',
                'name': "Región de Los Ríos",
                'comunas': ["Valdivia", "Corral", "Lanco", "Los Lagos", "Máfil", "Mariquina", "Paillaco", "Panguipulli", "La Unión", "Futrono", "Lago Ranco", "Río Bueno"],
            },
            {
                'number': 'CHI-15',
                'name': "Región de Los Ríos",
                'comunas': ["Valdivia", "Corral", "Lanco", "Los Lagos", "Máfil", "Mariquina", "Paillaco", "Panguipulli", "La Unión", "Futrono", "Lago Ranco", "Río Bueno"],
            },
            {
                'number': 'CHI-16',
                'name': "Región de Los Lagos",
                'comunas': ["Puerto Montt", "Calbuco", "Cochamó", "Fresia", "Frutillar", "Los Muermos", "Llanquihue", "Maullín", "Puerto Varas", "Castro", "Ancud", "Chonchi", "Curaco de Vélez", "Dalcahue", "Puqueldón", "Queilén", "Quellón", "Quemchi", "Quinchao", "Osorno", "Puerto Octay", "Purranque", "Puyehue", "Río Negro", "San Juan de la Costa", "San Pablo", "Chaitén", "Futaleufú", "Hualaihué", "Palena"]
            },
            {
                'number': 'CHI-17',
                'name': "Región de Aysén del General Carlos Ibáñez del Campo",
                'comunas': ["Coyhaique", "Lago Verde", "Aysén", "Cisnes", "Guaitecas", "Cochrane", "O'Higgins", "Tortel", "Chile Chico", "Río Ibáñez"]
            },
            {
                'number': 'CHI-18',
                'name': "Región de Magallanes y de la Antártica Chilena",
                'comunas': ["Punta Arenas", "Laguna Blanca", "Río Verde", "San Gregorio", "Cabo de Hornos", "Antártica", "Porvenir", "Primavera", "Timaukel", "Natales", "Torres del Paine"]
            },
        ]

# Crear un DataFrame de pandas solo con 'number' y 'name'
df = pd.DataFrame({'number': [region['number'] for region in regiones],
                   'name': [region['name'] for region in regiones]})

# Escribir el DataFrame en un archivo Excel
nombre_archivo = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx'
df.to_excel(nombre_archivo, index=False)

print(f"Se ha creado el archivo Excel '{nombre_archivo}' con los datos de las regiones.")
# Out:
# Se ha creado el archivo Excel '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx' con los datos de las regiones.

# %%
#Incorporar columna con la sentencia de insert para postgresql

# Leer el archivo Excel existente
archivo_excel = "/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx"
df = pd.read_excel(archivo_excel)

ID_CHILE = 'f107de1f-5553-4396-9b46-d4df8a1cbfc2'

# Crear una nueva columna con el formato deseado
df['sentencia_sql'] = df.apply(lambda row: f"INSERT INTO testcreates_region (id_region, nombre_region,pais_id) VALUES ('{row['number']}', '{row['name']}', '{ID_CHILE}');", axis=1)

# Guardar el DataFrame actualizado en un nuevo archivo Excel
nuevo_archivo_excel = "/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx"
df.to_excel(nuevo_archivo_excel, index=False)

print(f"Se ha creado el archivo '{nuevo_archivo_excel}' con la columna 'sentencia_sql'.")
# Out:
# Se ha creado el archivo '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx' con la columna 'sentencia_sql'.

# %% [markdown]
# # Sentencias SQL

# %% [markdown]
# ## 1. Asignaturas INSERT

# %%
for fila in range(len(ASIGNATURAS_DF)):
  ASIGNATURAS_DF.loc[fila,'SQL'] = f"'INSERT INTO TESTCREATES_ASIGNATURA(ID_ASIGNATURA,NOMBRE_ASIGNATURA) VALUES ('{ASIGNATURAS_DF.loc[fila, 'idAsignatura']}','{ASIGNATURAS_DF.loc[fila, 'nombreAsignatura']}');'"
  # No es necesario imprimir el texto

ASIGNATURAS_DF
# Out:
#   nombreAsignatura                          idAsignatura  \
# 0       Matemática  b73161cc-c0a9-483a-95b7-33a1276f2c35
#
#                                                  SQL
# 0  'INSERT INTO TESTCREATES_ASIGNATURA(ID_ASIGNAT...

# %% [markdown]
# ## 2. Niveles INSERT

# %%
for fila in range(len(NIVELES_DF)):
  NIVELES_DF.loc[fila,'SQL'] = f"'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_NIVEL,NOMBRE_NIVEL) VALUES ('{NIVELES_DF.loc[fila, 'idNivel']}','{NIVELES_DF.loc[fila, 'nombreNivel']}');'"
  # No es necesario imprimir el texto

NIVELES_DF
# Out:
#        nombreNivel                               idNivel  \
# 0   Primero Básico  2667df8b-cb8a-4377-8626-161de60cd73d
# 1  Segundo Básico   96fb93dc-7fe4-4110-bd38-4218ecc37c79
# 2   Tercero Básico  25abc845-f404-4e1d-b3b4-c9e4b37381fb
# 3    Cuarto Básico  bc3b68e4-5288-4945-b4aa-6c339557e0ed
# 4    Quinto Básico  9f140485-aac7-4af6-9f45-adda7084985f
# 5     Sexto Básico  1cd7f661-1f65-4b14-accb-9e0cc5f81216
# 6   Septimo Básico  747302c9-dc4f-48b0-88dd-0bd5649274d4
# 7    Octavo Básico  f64f1a6c-713e-43d3-bb99-dacfff9a7dbd
#
#                                                  SQL
# 0  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 1  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 2  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 3  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 4  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 5  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 6  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 7  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...

# %% [markdown]
# ## 3. Unidades INSERT

# %%
for fila in range(len(UNIDADES_DF)):
  UNIDADES_DF.loc[fila,'SQL'] = f"'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMBRE_UNIDAD, ASIGNATURA_ID) VALUES ('{UNIDADES_DF.loc[fila, 'idUnidad']}','{UNIDADES_DF.loc[fila, 'nombreUnidad']}','{UNIDADES_DF.loc[fila, 'nombreUnidad']}');'"
  # No es necesario imprimir el texto

UNIDADES_DF
# Out:
#                   nombreUnidad                              idUnidad  \
# 0        Números y Operaciones  7f458891-d25b-46aa-a87f-422dc290865c
# 1           Patrones y Álgebra  10ebecc7-f50f-42e8-9e75-ebe36e912cee
# 2                   Geometría   3b62230b-7cc7-42cd-a7df-7f82d3baa54f
# 3                    Medición   d0258cd1-691b-4bc2-82b8-3026bf7c3695
# 4         Datos y probabilidad  dda347e7-f96b-4c4e-bc88-b73d6df159f1
# 5                    Geometría  976f48a1-aa5d-4452-9e70-87d14d56ab13
# 6                     Medición  a0ccf162-ff05-4ef8-a5fb-de028d5488fd
# 7                      Números  c4738dce-adbd-4c07-b0a5-bf6e74ad27f1
# 8          Álgebra y Funciones  496f5d04-c7d9-4594-a26f-172da8c4de71
# 9  Probabilidad y Estadística   c621de03-87a4-4226-8355-aa41b953e61c
#
#                            idAsignatura  \
# 0  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 1  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 2  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 3  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 4  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 5  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 6  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 7  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 8  b73161cc-c0a9-483a-95b7-33a1276f2c35
# 9  b73161cc-c0a9-483a-95b7-33a1276f2c35
#
#                                                  SQL
# 0  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 1  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 2  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 3  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 4  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 5  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 6  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 7  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 8  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 9  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...

# %% [markdown]
# ## 4. Objetivo INSERT

# %%
for fila in range(len(DF_OBJETIVOS)):
  DF_OBJETIVOS.loc[fila,'SQL'] = f"'INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(ID_OBJETIVO_APRENDIZAJE,ENUNCIADO_OBJETIVO_APRENDIZAJE, UNIDAD_ID) VALUES ('{DF_OBJETIVOS.loc[fila, 'idObjetivo']}','{DF_OBJETIVOS.loc[fila, 'descObjetivo']}','{DF_OBJETIVOS.loc[fila, 'idUnidad']}');'"
  # No es necesario imprimir el texto

DF_OBJETIVOS.sample(2)
# Out:
#         nombreNivel            descripcionNivel nombreAsignatura  \
# 145   Cuarto Básico  Estudiantes de 9 a 10 años       Matemática
# 69   Tercero Básico   Estudiantes de 8 a 9 años       Matemática
#
#            nombreUnidad                                       descObjetivo  \
# 145            Medición  Demostrar que comprenden el concepto de área d...
# 69   Patrones y Álgebra  Generar, describir y registrar patrones numéri...
#
#      insert                               idNivel  \
# 145     NaN  dc7a9505-183a-4951-95fa-a96e02a4c71f
# 69      NaN  53dfd494-6b93-4a47-932c-e0905166c0f9
#
#                                idObjetivo  \
# 145  9d0bfa59-dc1c-4e40-9f0a-abd516f61471
# 69   79c762e6-6ece-4fdb-a9ae-9de1ec241a27
#
#                                  idUnidad  \
# 145  63260ccb-bd58-4354-a701-b8f6831fa0d8
# 69   44def628-2bd3-4dfc-9ade-0bac964a4a1b
#
#                                                    SQL
# 145  'INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(I...
# 69   'INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(I...

# %%
DF_OBJETIVOS['SQL'][0]
# Out:
# "'INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(ID_OBJETIVO_APRENDIZAJE,ENUNCIADO_OBJETIVO_APRENDIZAJE, UNIDAD_ID) VALUES ('ed69dead-eeb3-49e2-9f65-ccd4215b177a','Contar numeros del 0 al 100 de 1 en 1, de 2 en 2, de 5 en 5, y de 10 en 10, hacia delante y hacia atrás, empezando por cualquier número menor que 100.','9db56289-9f7c-4ab7-93bb-21bcb9c25901');'"
