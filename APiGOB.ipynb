# %% [markdown]
# <a href="https://colab.research.google.com/github/Bigote93/APIMINEDUC/blob/main/APiGOB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tratamiento de objetivos
#
# * [ x ] Unidad
# * [ x ] Nivel
# * [ x ] Asignatura
# * [ x ] Objetivo
#
# API confeccionada para gestionar Base de datos Mineduc Objetivos de aprendizaje de Primero a Octavo Basico

# %% [markdown]
# ## 1. Apertura de recursos de Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import uuid

# Rutas

objetivos_basica = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/OBJETIVOS_BASICA.xlsx'

INSERTS_UNIDADES = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/INSERTS_UNIDADES.xlsx'
INSERTS_NIVEL = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/INSERTS_NIVEL.xlsx'
INSERTS_ASIGNATURAS = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/INSERTS_ASIGNATURAS.xlsx'
INSERTS_OBJETIVOS = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/INSERTS_OBJETIVOS.xlsx'


# Crear el objeto Workbook para almacenar multiples ficheros
wb = pd.ExcelWriter(INSERTS_DOCUMENT)

# %% [markdown]
# ## 2. Recursos y diccionarios

# %%
DF_OBJETIVOS = pd.read_excel(objetivos_basica)
OBJETIVOS = DF_OBJETIVOS['descObjetivo']
ASIGNATURAS = DF_OBJETIVOS['nombreAsignatura'].unique()
NIVELES = DF_OBJETIVOS['nombreNivel'].unique()
UNIDADES = DF_OBJETIVOS['nombreUnidad'].unique()

# %% [markdown]
# ## 3. Asignar UUIID4 unico a cada asignatura

# %%
ASIGNATURAS_ARRAY = []
for asignatura in ASIGNATURAS:
  ASIGNATURAS_ARRAY.append([asignatura,str(uuid.uuid4())])

ASIGNATURAS_DF = pd.DataFrame(ASIGNATURAS_ARRAY,columns=['nombre','idAsignatura'])
ASIGNATURAS_DF.rename(columns = {'nombre': 'nombreAsignatura'}, inplace=True)

# %% [markdown]
# ## 4. Asignar UUIID4 unico a cada nivel

# %%
NIVELES_ARRAY = []
for nivel in NIVELES:
  NIVELES_ARRAY.append([nivel,str(uuid.uuid4())])

NIVELES_DF = pd.DataFrame(NIVELES_ARRAY,columns=['nombre','idNivel'])
NIVELES_DF.rename(columns = {'nombre': 'nombreNivel'}, inplace=True)



NIVELES_DF
# Out:
#        nombreNivel                               idNivel
# 0   Primero Básico  7d7d19bc-546e-458d-ad94-cdf012a2cbbe
# 1  Segundo Básico   13f11a8c-3773-4a94-b6e3-771bd1bb5aa7
# 2   Tercero Básico  13087d1f-278e-41e2-a468-a719fc9a2d5c
# 3    Cuarto Básico  380a8f8e-535c-4803-8a3a-41983a48ecaa
# 4    Quinto Básico  933f750a-33dc-498d-8373-92e0efc45b96
# 5     Sexto Básico  a249478f-2f05-4422-b221-468e87f19970
# 6   Septimo Básico  5bf9276c-dd81-49d0-8a56-447c114df962
# 7    Octavo Básico  4c6c4807-b8ec-4c3b-9e6a-a71db0a348b1

# %% [markdown]
# ## 5. Asignar UUIID4 a cada unidad

# %%
UNIDAD_ARRAY = []
for unidad in UNIDADES:
  UNIDAD_ARRAY.append([unidad,str(uuid.uuid4())])

UNIDADES_DF = pd.DataFrame(UNIDAD_ARRAY,columns=['nombre','idUnidad'])
UNIDADES_DF['idAsignatura'] = ASIGNATURAS_DF[ASIGNATURAS_DF['nombreAsignatura'] == 'Matemática'].iloc[0, 1]
UNIDADES_DF.rename(columns = {'nombre': 'nombreUnidad'}, inplace=True)


UNIDADES_DF
# Out:
#                   nombreUnidad                              idUnidad  \
# 0        Números y Operaciones  cccd340b-bb51-41cc-9c57-762067f1cc1c
# 1           Patrones y Álgebra  82471a07-b393-4ae2-a9cf-a137f7f2cdd0
# 2                   Geometría   c704cb3f-b05e-464d-a379-6e5e4b9d4c6b
# 3                    Medición   79503b44-732d-4ae5-9247-c8b042e087ed
# 4         Datos y probabilidad  3a9dd15d-7b01-4aa1-a69e-05f516ac56de
# 5                    Geometría  06bb6598-013d-47b7-b0ba-f17bc6ad1e07
# 6                     Medición  e5cf66dc-a81f-405d-bb06-90ee0d0f78ac
# 7                      Números  8deb3061-14ba-46fd-8c23-614c08567ea0
# 8          Álgebra y Funciones  0d910cbe-0404-43f7-93e2-a64cca2ab892
# 9  Probabilidad y Estadística   e697c987-81b3-478d-8c09-4c3b22a9221c
#
#                            idAsignatura
# 0  c1c93f4c-451e-4a54-9074-163711e7c855
# 1  c1c93f4c-451e-4a54-9074-163711e7c855
# 2  c1c93f4c-451e-4a54-9074-163711e7c855
# 3  c1c93f4c-451e-4a54-9074-163711e7c855
# 4  c1c93f4c-451e-4a54-9074-163711e7c855
# 5  c1c93f4c-451e-4a54-9074-163711e7c855
# 6  c1c93f4c-451e-4a54-9074-163711e7c855
# 7  c1c93f4c-451e-4a54-9074-163711e7c855
# 8  c1c93f4c-451e-4a54-9074-163711e7c855
# 9  c1c93f4c-451e-4a54-9074-163711e7c855

# %% [markdown]
# ## 6. Asignar UUIID4 a cada objetivo

# %%
OBJETIVO_ARRAY = []
for objetivo in OBJETIVOS:
  OBJETIVO_ARRAY.append([objetivo,str(uuid.uuid4())])

OBJETIVOS_DF = pd.DataFrame(OBJETIVO_ARRAY,columns=['nombre','idObjetivo'])
OBJETIVOS_DF.rename(columns = {'nombre': 'descObjetivo'}, inplace=True)


OBJETIVOS_DF
# Out:
#                                           descObjetivo  \
# 0    Contar numeros del 0 al 100 de 1 en 1, de 2 en...
# 1    Identificar el orden de los elementos de una s...
# 2    Leer números del 0 al 20 y representarlos en f...
# 3    Comparar y ordenar números del 0 al 20 de meno...
# 4    Estimar cantidades hasta 20 en situaciones con...
# ..                                                 ...
# 177  Describir la posición y el movimiento (traslac...
# 178  Componer rotaciones, traslaciones y reflexione...
# 179  Mostrar que comprenden las medidas de posición...
# 180  Evaluar la forma en que los datos están presen...
# 181  Explicar el principio combinatorio multiplicat...
#
#                                idObjetivo
# 0    76f0f920-a52e-492f-b2c4-034330fa1d7b
# 1    48832695-f448-4096-92d7-7b77ba0cf6f7
# 2    b4cbc20a-c0c6-4a80-88a4-e6fe0f15395f
# 3    1b93531c-139e-4309-b7aa-46b3ec7cded4
# 4    81867d46-8b40-4d59-8050-658451758f15
# ..                                    ...
# 177  65501d31-992a-4242-a382-6b80b415a88e
# 178  3e397efe-2d3d-4e77-9cbe-fcda186f260b
# 179  60c9e036-ea34-4cd4-a7d9-936eb3b0efe5
# 180  7f2df1b1-146f-49bf-ba59-0a3aa8a66dc4
# 181  6d0ec5cc-f593-4746-98f8-09f06c6f77ee
#
# [182 rows x 2 columns]

# %% [markdown]
# ## Unificar columnas

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(NIVELES_DF[['nombreNivel','idNivel']], how='inner', left_on='nombreNivel', right_on='nombreNivel')
DF_OBJETIVOS.sample(2)
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 154  Septimo Básico  Estudiantes de 12 a 13 años       Matemática
# 168   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
#
#             nombreUnidad                                       descObjetivo  \
# 154  Álgebra y Funciones  Modelar y resolver problemas diversos de la vi...
# 168              Números  Mostrar que comprenden las raíces cuadradas de...
#
#                                   idNivel
# 154  5bf9276c-dd81-49d0-8a56-447c114df962
# 168  4c6c4807-b8ec-4c3b-9e6a-a71db0a348b1

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(OBJETIVOS_DF, how='inner', on='descObjetivo')

DF_OBJETIVOS.sample(2)
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 84    Cuarto Básico   Estudiantes de 9 a 10 años       Matemática
# 164  Septimo Básico  Estudiantes de 12 a 13 años       Matemática
#
#                     nombreUnidad  \
# 84                     Geometría
# 164  Probabilidad y Estadística
#
#                                           descObjetivo  \
# 84   Demostrar que comprenden una línea de simetría...
# 164  Comparar las frecuencias relativas de un event...
#
#                                   idNivel  \
# 84   380a8f8e-535c-4803-8a3a-41983a48ecaa
# 164  5bf9276c-dd81-49d0-8a56-447c114df962
#
#                                idObjetivo
# 84   a60dc0f8-4650-4c96-83b3-f8144c4d2d5d
# 164  75bcd477-f4d3-4f96-a9e8-51dfc3bf2b88

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(UNIDADES_DF[['nombreUnidad','idUnidad']], how='inner', on='nombreUnidad')

DF_OBJETIVOS
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 0    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 1    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 2    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 3    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 4    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# ..              ...                          ...              ...
# 177  Septimo Básico  Estudiantes de 12 a 13 años       Matemática
# 178  Septimo Básico  Estudiantes de 12 a 13 años       Matemática
# 179   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
# 180   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
# 181   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
#
#                     nombreUnidad  \
# 0          Números y Operaciones
# 1          Números y Operaciones
# 2          Números y Operaciones
# 3          Números y Operaciones
# 4          Números y Operaciones
# ..                           ...
# 177  Probabilidad y Estadística
# 178  Probabilidad y Estadística
# 179  Probabilidad y Estadística
# 180  Probabilidad y Estadística
# 181  Probabilidad y Estadística
#
#                                           descObjetivo  \
# 0    Contar numeros del 0 al 100 de 1 en 1, de 2 en...
# 1    Identificar el orden de los elementos de una s...
# 2    Leer números del 0 al 20 y representarlos en f...
# 3    Comparar y ordenar números del 0 al 20 de meno...
# 4    Estimar cantidades hasta 20 en situaciones con...
# ..                                                 ...
# 177  Explicar las probabilidades de eventos obtenid...
# 178  Comparar las frecuencias relativas de un event...
# 179  Mostrar que comprenden las medidas de posición...
# 180  Evaluar la forma en que los datos están presen...
# 181  Explicar el principio combinatorio multiplicat...
#
#                                   idNivel  \
# 0    7d7d19bc-546e-458d-ad94-cdf012a2cbbe
# 1    7d7d19bc-546e-458d-ad94-cdf012a2cbbe
# 2    7d7d19bc-546e-458d-ad94-cdf012a2cbbe
# 3    7d7d19bc-546e-458d-ad94-cdf012a2cbbe
# 4    7d7d19bc-546e-458d-ad94-cdf012a2cbbe
# ..                                    ...
# 177  5bf9276c-dd81-49d0-8a56-447c114df962
# 178  5bf9276c-dd81-49d0-8a56-447c114df962
# 179  4c6c4807-b8ec-4c3b-9e6a-a71db0a348b1
# 180  4c6c4807-b8ec-4c3b-9e6a-a71db0a348b1
# 181  4c6c4807-b8ec-4c3b-9e6a-a71db0a348b1
#
#                                idObjetivo  \
# 0    76f0f920-a52e-492f-b2c4-034330fa1d7b
# 1    48832695-f448-4096-92d7-7b77ba0cf6f7
# 2    b4cbc20a-c0c6-4a80-88a4-e6fe0f15395f
# 3    1b93531c-139e-4309-b7aa-46b3ec7cded4
# 4    81867d46-8b40-4d59-8050-658451758f15
# ..                                    ...
# 177  435be63f-415a-4247-a524-0d707b62a323
# 178  75bcd477-f4d3-4f96-a9e8-51dfc3bf2b88
# 179  60c9e036-ea34-4cd4-a7d9-936eb3b0efe5
# 180  7f2df1b1-146f-49bf-ba59-0a3aa8a66dc4
# 181  6d0ec5cc-f593-4746-98f8-09f06c6f77ee
#
#                                  idUnidad
# 0    cccd340b-bb51-41cc-9c57-762067f1cc1c
# 1    cccd340b-bb51-41cc-9c57-762067f1cc1c
# 2    cccd340b-bb51-41cc-9c57-762067f1cc1c
# 3    cccd340b-bb51-41cc-9c57-762067f1cc1c
# 4    cccd340b-bb51-41cc-9c57-762067f1cc1c
# ..                                    ...
# 177  e697c987-81b3-478d-8c09-4c3b22a9221c
# 178  e697c987-81b3-478d-8c09-4c3b22a9221c
# 179  e697c987-81b3-478d-8c09-4c3b22a9221c
# 180  e697c987-81b3-478d-8c09-4c3b22a9221c
# 181  e697c987-81b3-478d-8c09-4c3b22a9221c
#
# [182 rows x 8 columns]

# %% [markdown]
# # Sentencias SQL

# %% [markdown]
# ## 1. Asignaturas INSERT

# %%
for fila in range(len(ASIGNATURAS_DF)):
  ASIGNATURAS_DF.loc[fila,'SQL'] = f"'INSERT INTO TESTCREATES_ASIGNATURA(ID_ASIGNATURA,NOMBRE_ASIGNATURA) VALUES ('{ASIGNATURAS_DF.loc[fila, 'idAsignatura']}','{ASIGNATURAS_DF.loc[fila, 'nombreAsignatura']}');'"

#Crear fichero asignaturas
ASIGNATURAS_DF.to_excel(INSERTS_ASIGNATURAS, sheet_name='Asignaturas')

ASIGNATURAS_DF
# Out:
#   nombreAsignatura                          idAsignatura  \
# 0       Matemática  c1c93f4c-451e-4a54-9074-163711e7c855
#
#                                                  SQL
# 0  'INSERT INTO TESTCREATES_ASIGNATURA(ID_ASIGNAT...

# %% [markdown]
# ## 2. Niveles INSERT

# %%
for fila in range(len(NIVELES_DF)):
  NIVELES_DF.loc[fila,'SQL'] = f"'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_NIVEL,NOMBRE_NIVEL) VALUES ('{NIVELES_DF.loc[fila, 'idNivel']}','{NIVELES_DF.loc[fila, 'nombreNivel']}');'"

#Crear fichero niveles
NIVELES_DF.to_excel(INSERTS_NIVEL, sheet_name='Niveles')


NIVELES_DF
# Out:
#        nombreNivel                               idNivel  \
# 0   Primero Básico  7d7d19bc-546e-458d-ad94-cdf012a2cbbe
# 1  Segundo Básico   13f11a8c-3773-4a94-b6e3-771bd1bb5aa7
# 2   Tercero Básico  13087d1f-278e-41e2-a468-a719fc9a2d5c
# 3    Cuarto Básico  380a8f8e-535c-4803-8a3a-41983a48ecaa
# 4    Quinto Básico  933f750a-33dc-498d-8373-92e0efc45b96
# 5     Sexto Básico  a249478f-2f05-4422-b221-468e87f19970
# 6   Septimo Básico  5bf9276c-dd81-49d0-8a56-447c114df962
# 7    Octavo Básico  4c6c4807-b8ec-4c3b-9e6a-a71db0a348b1
#
#                                                  SQL
# 0  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 1  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 2  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 3  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 4  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 5  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 6  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...
# 7  'INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_N...

# %% [markdown]
# ## 3. Unidades INSERT

# %%
for fila in range(len(UNIDADES_DF)):
  UNIDADES_DF.loc[fila,'SQL'] = f"'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMBRE_UNIDAD, ASIGNATURA_ID) VALUES ('{UNIDADES_DF.loc[fila, 'idUnidad']}','{UNIDADES_DF.loc[fila, 'nombreUnidad']}','{UNIDADES_DF.loc[fila, 'nombreUnidad']}');'"

#Crear fichero unidades
UNIDADES_DF.to_excel(INSERTS_UNIDADES, sheet_name='Unidades')

UNIDADES_DF
# Out:
#                   nombreUnidad                              idUnidad  \
# 0        Números y Operaciones  cccd340b-bb51-41cc-9c57-762067f1cc1c
# 1           Patrones y Álgebra  82471a07-b393-4ae2-a9cf-a137f7f2cdd0
# 2                   Geometría   c704cb3f-b05e-464d-a379-6e5e4b9d4c6b
# 3                    Medición   79503b44-732d-4ae5-9247-c8b042e087ed
# 4         Datos y probabilidad  3a9dd15d-7b01-4aa1-a69e-05f516ac56de
# 5                    Geometría  06bb6598-013d-47b7-b0ba-f17bc6ad1e07
# 6                     Medición  e5cf66dc-a81f-405d-bb06-90ee0d0f78ac
# 7                      Números  8deb3061-14ba-46fd-8c23-614c08567ea0
# 8          Álgebra y Funciones  0d910cbe-0404-43f7-93e2-a64cca2ab892
# 9  Probabilidad y Estadística   e697c987-81b3-478d-8c09-4c3b22a9221c
#
#                            idAsignatura  \
# 0  c1c93f4c-451e-4a54-9074-163711e7c855
# 1  c1c93f4c-451e-4a54-9074-163711e7c855
# 2  c1c93f4c-451e-4a54-9074-163711e7c855
# 3  c1c93f4c-451e-4a54-9074-163711e7c855
# 4  c1c93f4c-451e-4a54-9074-163711e7c855
# 5  c1c93f4c-451e-4a54-9074-163711e7c855
# 6  c1c93f4c-451e-4a54-9074-163711e7c855
# 7  c1c93f4c-451e-4a54-9074-163711e7c855
# 8  c1c93f4c-451e-4a54-9074-163711e7c855
# 9  c1c93f4c-451e-4a54-9074-163711e7c855
#
#                                                  SQL
# 0  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 1  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 2  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 3  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 4  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 5  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 6  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 7  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 8  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...
# 9  'INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMB...

# %% [markdown]
# ## 4. Objetivo INSERT

# %%
for fila in range(len(DF_OBJETIVOS)):
  DF_OBJETIVOS.loc[fila,'SQL'] = f"'INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(ID_OBJETIVO_APRENDIZAJE,ENUNCIADO_OBJETIVO_APRENDIZAJE, UNIDAD_ID) VALUES ('{DF_OBJETIVOS.loc[fila, 'idObjetivo']}','{DF_OBJETIVOS.loc[fila, 'descObjetivo']}','{DF_OBJETIVOS.loc[fila, 'idUnidad']}');'"

#Crear fichero unidades
DF_OBJETIVOS.to_excel(INSERTS_OBJETIVOS, sheet_name='Objetivos')

DF_OBJETIVOS.sample(2)
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 111  Tercero Básico    Estudiantes de 8 a 9 años       Matemática
# 74    Quinto Básico  Estudiantes de 10 a 11 años       Matemática
#
#            nombreUnidad                                       descObjetivo  \
# 111           Geometría  Demostrar que comprenden el concepto de ángulo...
# 74   Patrones y Álgebra  Resolver problemas, usando ecuaciones e inecua...
#
#                                   idNivel  \
# 111  13087d1f-278e-41e2-a468-a719fc9a2d5c
# 74   933f750a-33dc-498d-8373-92e0efc45b96
#
#                                idObjetivo  \
# 111  023ecd35-41c0-4b91-86fc-3a4fbf8fd9c3
# 74   4216bae9-5629-4754-8252-5014e6d37c72
#
#                                  idUnidad  \
# 111  06bb6598-013d-47b7-b0ba-f17bc6ad1e07
# 74   82471a07-b393-4ae2-a9cf-a137f7f2cdd0
#
#                                                    SQL
# 111  'INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(I...
# 74   'INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(I...
