# %% [markdown]
# <a href="https://colab.research.google.com/github/Bigote93/APIMINEDUC/blob/main/APiGOB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tratamiento de objetivos
#
# * [ x ] Unidad
# * [ x ] Nivel
# * [ x ] Asignatura
# * [ x ] Objetivo
#
# API confeccionada para gestionar Base de datos Mineduc Objetivos de aprendizaje de Primero a Octavo Basico

# %% [markdown]
# ## 1. Apertura de recursos de Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import uuid

# Rutas

objetivos_basica = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/OBJETIVOS_BASICA.xlsx'

INSERTS_UNIDADES = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/INSERTS_UNIDADES.xlsx'
INSERTS_NIVEL = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/INSERTS_NIVEL.xlsx'
INSERTS_ASIGNATURAS = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/INSERTS_ASIGNATURAS.xlsx'
INSERTS_OBJETIVOS = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/INSERTS_OBJETIVOS.xlsx'

# %% [markdown]
# ## 2. Recursos y diccionarios

# %%
DF_OBJETIVOS = pd.read_excel(objetivos_basica)
OBJETIVOS = DF_OBJETIVOS['descObjetivo']
ASIGNATURAS = DF_OBJETIVOS['nombreAsignatura'].unique()
NIVELES = DF_OBJETIVOS['nombreNivel'].unique()
UNIDADES = DF_OBJETIVOS['nombreUnidad'].unique()

# Definir una función para extraer las primeras dos letras de cada palabra y el primerconjunto id
def extract_initials(text,separator):

  if separator == '-':
    segmentos = text.split('-')
    return segmentos[0]
  elif separator == ' ':
    palabras = text.split()
    slug = palabras[0][0:3]
    return slug

# %% [markdown]
# ## 3. Asignar UUIID4 unico a cada asignatura

# %%
ASIGNATURAS_ARRAY = []
for asignatura in ASIGNATURAS:
  ASIGNATURAS_ARRAY.append([asignatura,str(uuid.uuid4())])

ASIGNATURAS_DF = pd.DataFrame(ASIGNATURAS_ARRAY,columns=['nombre','idAsignatura'])

ASIGNATURAS_DF['slug'] = ASIGNATURAS_DF['nombre'].apply(extract_initials, separator = ' ') + ASIGNATURAS_DF['idAsignatura'].apply(extract_initials, separator= '-')
ASIGNATURAS_DF.rename(columns = {'nombre': 'nombreAsignatura'}, inplace=True)

ASIGNATURAS_DF
# Out:
#   nombreAsignatura                          idAsignatura         slug
# 0       Matemática  fc47d4df-2a53-4c0e-91b0-892f6027fa6c  Matfc47d4df

# %% [markdown]
# ## 4. Asignar UUIID4 unico a cada nivel

# %%
NIVELES_ARRAY = []
for nivel in NIVELES:
  NIVELES_ARRAY.append([nivel,str(uuid.uuid4())])

NIVELES_DF = pd.DataFrame(NIVELES_ARRAY,columns=['nombre','idNivel'])
NIVELES_DF['slug'] = NIVELES_DF['nombre'].apply(extract_initials, separator = ' ') + NIVELES_DF['idNivel'].apply(extract_initials, separator= '-')
NIVELES_DF.rename(columns = {'nombre': 'nombreNivel'}, inplace=True)

NIVELES_DF
# Out:
#        nombreNivel                               idNivel         slug
# 0   Primero Básico  08f54eda-0752-4343-acaa-470b4a7812e4  Pri08f54eda
# 1  Segundo Básico   9861a542-aeff-44c2-b0ce-632292688a86  Seg9861a542
# 2   Tercero Básico  59f4ce56-c29c-4102-9183-722d39bef6a6  Ter59f4ce56
# 3    Cuarto Básico  50f20b6e-731c-4890-ad22-29720cf6ddb3  Cua50f20b6e
# 4    Quinto Básico  2f7b8dfe-fc51-463d-99c9-d1195a4c62e2  Qui2f7b8dfe
# 5     Sexto Básico  3732f6b9-0169-4b3e-88ff-60bd6d6717f9  Sex3732f6b9
# 6   Septimo Básico  9a399bec-7d49-44ff-a774-47f79ce31cf2  Sep9a399bec
# 7    Octavo Básico  3ccfec3c-c64e-4742-8fdc-64a40756d912  Oct3ccfec3c

# %% [markdown]
# ## 5. Asignar UUIID4 a cada unidad

# %%
UNIDAD_ARRAY = []
for unidad in UNIDADES:
  UNIDAD_ARRAY.append([unidad,str(uuid.uuid4())])

UNIDADES_DF = pd.DataFrame(UNIDAD_ARRAY,columns=['nombre','idUnidad'])
UNIDADES_DF['slug'] = UNIDADES_DF['nombre'].apply(extract_initials, separator = ' ') + UNIDADES_DF['idUnidad'].apply(extract_initials, separator= '-')
UNIDADES_DF['idAsignatura'] = ASIGNATURAS_DF[ASIGNATURAS_DF['nombreAsignatura'] == 'Matemática'].iloc[0, 1]
UNIDADES_DF.rename(columns = {'nombre': 'nombreUnidad'}, inplace=True)


UNIDADES_DF
# Out:
#                   nombreUnidad                              idUnidad  \
# 0        Números y Operaciones  907413a1-dede-47d6-98f9-98205a74ec39
# 1           Patrones y Álgebra  5a655197-c40a-4b4e-9bdf-67b5137a4be0
# 2                   Geometría   6ad0d2bc-8d20-4a31-afbf-1ae08ff3cbd3
# 3                    Medición   454375f7-fe55-4202-b2c7-85d85943e2ef
# 4         Datos y probabilidad  ab048a18-469c-4e4c-85db-993b99856efe
# 5                    Geometría  b4ffcc51-f075-45f3-8e13-afcee30d7122
# 6                     Medición  735b9a27-38d8-4efd-a786-465f6f6cec2c
# 7                      Números  a0f68191-dcd4-49de-9e6a-8e64f3165c49
# 8          Álgebra y Funciones  17cb30fc-9ffa-4d8a-b6d1-e51db64e90d0
# 9  Probabilidad y Estadística   d029a99e-2a8c-4981-98d2-5f10ba27205b
#
#           slug                          idAsignatura
# 0  Núm907413a1  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 1  Pat5a655197  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 2  Geo6ad0d2bc  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 3  Med454375f7  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 4  Datab048a18  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 5  Geob4ffcc51  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 6  Med735b9a27  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 7  Núma0f68191  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 8  Álg17cb30fc  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 9  Prod029a99e  fc47d4df-2a53-4c0e-91b0-892f6027fa6c

# %% [markdown]
# ## 6. Asignar UUIID4 a cada objetivo

# %%
OBJETIVO_ARRAY = []
for objetivo in OBJETIVOS:
  OBJETIVO_ARRAY.append([objetivo,str(uuid.uuid4())])

OBJETIVOS_DF = pd.DataFrame(OBJETIVO_ARRAY,columns=['nombre','idObjetivo'])
OBJETIVOS_DF['slug'] = OBJETIVOS_DF['nombre'].apply(extract_initials, separator = ' ') + OBJETIVOS_DF['idObjetivo'].apply(extract_initials, separator= '-')
OBJETIVOS_DF.rename(columns = {'nombre': 'descObjetivo'}, inplace=True)


OBJETIVOS_DF
# Out:
#                                           descObjetivo  \
# 0    Contar numeros del 0 al 100 de 1 en 1, de 2 en...
# 1    Identificar el orden de los elementos de una s...
# 2    Leer números del 0 al 20 y representarlos en f...
# 3    Comparar y ordenar números del 0 al 20 de meno...
# 4    Estimar cantidades hasta 20 en situaciones con...
# ..                                                 ...
# 177  Describir la posición y el movimiento (traslac...
# 178  Componer rotaciones, traslaciones y reflexione...
# 179  Mostrar que comprenden las medidas de posición...
# 180  Evaluar la forma en que los datos están presen...
# 181  Explicar el principio combinatorio multiplicat...
#
#                                idObjetivo         slug
# 0    2f38ffa7-3dda-4bf9-baec-f2c74a176844  Con2f38ffa7
# 1    65fcbfde-ad31-4341-9ebb-e922e5418867  Ide65fcbfde
# 2    41c8cd86-b255-465a-92ed-7fe66f3d4fb0  Lee41c8cd86
# 3    5a83bb08-692c-411f-a60c-5a8a0a2d9eed  Com5a83bb08
# 4    d0bf8186-9e7d-4175-a33d-9e1c0513358e  Estd0bf8186
# ..                                    ...          ...
# 177  7fc74bd6-d87c-4f73-8302-f55576963f4b  Des7fc74bd6
# 178  c2f14489-5256-4621-b803-46ef99cb3264  Comc2f14489
# 179  d3582cc8-ab7d-4bbc-ab3c-7afaa95c1ccd  Mosd3582cc8
# 180  4947b659-afcb-4b4b-ab0c-bc93a29d3928  Eva4947b659
# 181  debbdb60-d335-4b96-ad1b-227080894d4e  Expdebbdb60
#
# [182 rows x 3 columns]

# %% [markdown]
# ## Unificar columnas

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(NIVELES_DF[['nombreNivel','idNivel']], how='inner', left_on='nombreNivel', right_on='nombreNivel')
DF_OBJETIVOS.sample(2)
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 15   Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 171   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
#
#             nombreUnidad                                       descObjetivo  \
# 15             Medición   Usar unidades no estandarizadas de tiempo para...
# 171  Álgebra y Funciones  Mostrar que comprenden la noción de función po...
#
#                                   idNivel
# 15   08f54eda-0752-4343-acaa-470b4a7812e4
# 171  3ccfec3c-c64e-4742-8fdc-64a40756d912

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(OBJETIVOS_DF[['descObjetivo','idObjetivo','slug']], how='inner', on='descObjetivo')

DF_OBJETIVOS.sample(2)
# Out:
#        nombreNivel             descripcionNivel nombreAsignatura  \
# 142   Sexto Básico  Estudiantes de 11 a 12 años       Matemática
# 71   Cuarto Básico   Estudiantes de 9 a 10 años       Matemática
#
#               nombreUnidad                                       descObjetivo  \
# 142               Medición  Calcular ángulos en rectas paralelas cortadas ...
# 71   Números y Operaciones  Fundamentar y aplicar las propiedades del 0 y ...
#
#                                   idNivel  \
# 142  3732f6b9-0169-4b3e-88ff-60bd6d6717f9
# 71   50f20b6e-731c-4890-ad22-29720cf6ddb3
#
#                                idObjetivo         slug
# 142  fd6f112e-158e-4fb8-9bbd-1f15aaaeb926  Calfd6f112e
# 71   493d9795-bc6d-4594-b194-69a9e1390c57  Fun493d9795

# %%
DF_OBJETIVOS = DF_OBJETIVOS.merge(UNIDADES_DF[['nombreUnidad','idUnidad']], how='inner', on='nombreUnidad')

DF_OBJETIVOS
# Out:
#         nombreNivel             descripcionNivel nombreAsignatura  \
# 0    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 1    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 2    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 3    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# 4    Primero Básico    Estudiantes de 6 a 7 años       Matemática
# ..              ...                          ...              ...
# 177  Septimo Básico  Estudiantes de 12 a 13 años       Matemática
# 178  Septimo Básico  Estudiantes de 12 a 13 años       Matemática
# 179   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
# 180   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
# 181   Octavo Básico  Estudiantes de 13 a 14 años       Matemática
#
#                     nombreUnidad  \
# 0          Números y Operaciones
# 1          Números y Operaciones
# 2          Números y Operaciones
# 3          Números y Operaciones
# 4          Números y Operaciones
# ..                           ...
# 177  Probabilidad y Estadística
# 178  Probabilidad y Estadística
# 179  Probabilidad y Estadística
# 180  Probabilidad y Estadística
# 181  Probabilidad y Estadística
#
#                                           descObjetivo  \
# 0    Contar numeros del 0 al 100 de 1 en 1, de 2 en...
# 1    Identificar el orden de los elementos de una s...
# 2    Leer números del 0 al 20 y representarlos en f...
# 3    Comparar y ordenar números del 0 al 20 de meno...
# 4    Estimar cantidades hasta 20 en situaciones con...
# ..                                                 ...
# 177  Explicar las probabilidades de eventos obtenid...
# 178  Comparar las frecuencias relativas de un event...
# 179  Mostrar que comprenden las medidas de posición...
# 180  Evaluar la forma en que los datos están presen...
# 181  Explicar el principio combinatorio multiplicat...
#
#                                   idNivel  \
# 0    08f54eda-0752-4343-acaa-470b4a7812e4
# 1    08f54eda-0752-4343-acaa-470b4a7812e4
# 2    08f54eda-0752-4343-acaa-470b4a7812e4
# 3    08f54eda-0752-4343-acaa-470b4a7812e4
# 4    08f54eda-0752-4343-acaa-470b4a7812e4
# ..                                    ...
# 177  9a399bec-7d49-44ff-a774-47f79ce31cf2
# 178  9a399bec-7d49-44ff-a774-47f79ce31cf2
# 179  3ccfec3c-c64e-4742-8fdc-64a40756d912
# 180  3ccfec3c-c64e-4742-8fdc-64a40756d912
# 181  3ccfec3c-c64e-4742-8fdc-64a40756d912
#
#                                idObjetivo         slug  \
# 0    2f38ffa7-3dda-4bf9-baec-f2c74a176844  Con2f38ffa7
# 1    65fcbfde-ad31-4341-9ebb-e922e5418867  Ide65fcbfde
# 2    41c8cd86-b255-465a-92ed-7fe66f3d4fb0  Lee41c8cd86
# 3    5a83bb08-692c-411f-a60c-5a8a0a2d9eed  Com5a83bb08
# 4    d0bf8186-9e7d-4175-a33d-9e1c0513358e  Estd0bf8186
# ..                                    ...          ...
# 177  d7fe7c01-38a3-4307-92a3-14d23d60b7c9  Expd7fe7c01
# 178  7bdb8c08-a51e-4c7d-bd53-a67d426e91da  Com7bdb8c08
# 179  d3582cc8-ab7d-4bbc-ab3c-7afaa95c1ccd  Mosd3582cc8
# 180  4947b659-afcb-4b4b-ab0c-bc93a29d3928  Eva4947b659
# 181  debbdb60-d335-4b96-ad1b-227080894d4e  Expdebbdb60
#
#                                  idUnidad
# 0    907413a1-dede-47d6-98f9-98205a74ec39
# 1    907413a1-dede-47d6-98f9-98205a74ec39
# 2    907413a1-dede-47d6-98f9-98205a74ec39
# 3    907413a1-dede-47d6-98f9-98205a74ec39
# 4    907413a1-dede-47d6-98f9-98205a74ec39
# ..                                    ...
# 177  d029a99e-2a8c-4981-98d2-5f10ba27205b
# 178  d029a99e-2a8c-4981-98d2-5f10ba27205b
# 179  d029a99e-2a8c-4981-98d2-5f10ba27205b
# 180  d029a99e-2a8c-4981-98d2-5f10ba27205b
# 181  d029a99e-2a8c-4981-98d2-5f10ba27205b
#
# [182 rows x 9 columns]

# %% [markdown]
# # Sentencias SQL

# %% [markdown]
# ## 1. Asignaturas INSERT

# %%
for fila in range(len(ASIGNATURAS_DF)):
  ASIGNATURAS_DF.loc[fila,'SQL'] = f"INSERT INTO TESTCREATES_ASIGNATURA(ID_ASIGNATURA,NOMBRE_ASIGNATURA) VALUES ('{ASIGNATURAS_DF.loc[fila, 'idAsignatura']}','{ASIGNATURAS_DF.loc[fila, 'nombreAsignatura']}');"

#Crear fichero asignaturas
ASIGNATURAS_DF.to_excel(INSERTS_ASIGNATURAS, sheet_name='Asignaturas')

ASIGNATURAS_DF
# Out:
#   nombreAsignatura                          idAsignatura         slug  \
# 0       Matemática  fc47d4df-2a53-4c0e-91b0-892f6027fa6c  Matfc47d4df
#
#                                                  SQL
# 0  INSERT INTO TESTCREATES_ASIGNATURA(ID_ASIGNATU...

# %% [markdown]
# ## 2. Niveles INSERT

# %%
for fila in range(len(NIVELES_DF)):
  NIVELES_DF.loc[fila,'SQL'] = f"INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_NIVEL,NOMBRE_NIVEL) VALUES ('{NIVELES_DF.loc[fila, 'idNivel']}','{NIVELES_DF.loc[fila, 'nombreNivel']}');"

#Crear fichero niveles
NIVELES_DF.to_excel(INSERTS_NIVEL, sheet_name='Niveles')


NIVELES_DF.sample(2)
# Out:
#       nombreNivel                               idNivel         slug  \
# 5    Sexto Básico  3732f6b9-0169-4b3e-88ff-60bd6d6717f9  Sex3732f6b9
# 6  Septimo Básico  9a399bec-7d49-44ff-a774-47f79ce31cf2  Sep9a399bec
#
#                                                  SQL
# 5  INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_NI...
# 6  INSERT INTO TESTCREATES_NIVELESCOLARIDAD(ID_NI...

# %% [markdown]
# ## 3. Unidades INSERT

# %%
for fila in range(len(UNIDADES_DF)):
  UNIDADES_DF.loc[fila,'SQL'] = f"INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMBRE_UNIDAD, ASIGNATURA_ID) VALUES ('{UNIDADES_DF.loc[fila, 'idUnidad']}','{UNIDADES_DF.loc[fila, 'nombreUnidad']}','{UNIDADES_DF.loc[fila, 'idAsignatura']}');"

#Crear fichero unidades
UNIDADES_DF.to_excel(INSERTS_UNIDADES, sheet_name='Unidades')

UNIDADES_DF.sample(2)
# Out:
#             nombreUnidad                              idUnidad         slug  \
# 2             Geometría   6ad0d2bc-8d20-4a31-afbf-1ae08ff3cbd3  Geo6ad0d2bc
# 0  Números y Operaciones  907413a1-dede-47d6-98f9-98205a74ec39  Núm907413a1
#
#                            idAsignatura  \
# 2  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
# 0  fc47d4df-2a53-4c0e-91b0-892f6027fa6c
#
#                                                  SQL
# 2  INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMBR...
# 0  INSERT INTO TESTCREATES_UNIDAD(ID_UNIDAD,NOMBR...

# %% [markdown]
# ## 4. Objetivo INSERT

# %%
for fila in range(len(DF_OBJETIVOS)):
  DF_OBJETIVOS.loc[fila,'SQL'] = f"INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(ID_OBJETIVO_APRENDIZAJE,ENUNCIADO_OBJETIVO_APRENDIZAJE, UNIDAD_ID) VALUES ('{DF_OBJETIVOS.loc[fila, 'idObjetivo']}','{DF_OBJETIVOS.loc[fila, 'descObjetivo']}','{DF_OBJETIVOS.loc[fila, 'idUnidad']}');"

#Crear fichero unidades
DF_OBJETIVOS.to_excel(INSERTS_OBJETIVOS, sheet_name='Objetivos')

DF_OBJETIVOS.sample(2)
# Out:
#       nombreNivel             descripcionNivel nombreAsignatura  \
# 73  Quinto Básico  Estudiantes de 10 a 11 años       Matemática
# 98  Quinto Básico  Estudiantes de 10 a 11 años       Matemática
#
#             nombreUnidad                                       descObjetivo  \
# 73    Patrones y Álgebra  Descubrir alguna regla que explique una sucesi...
# 98  Datos y probabilidad  Comparar probabilidades de distintos eventos s...
#
#                                  idNivel  \
# 73  2f7b8dfe-fc51-463d-99c9-d1195a4c62e2
# 98  2f7b8dfe-fc51-463d-99c9-d1195a4c62e2
#
#                               idObjetivo         slug  \
# 73  15a1aa33-8a49-41aa-ba42-d75513d9ea07  Des15a1aa33
# 98  cada631e-d5b4-4832-bbbc-540858f93912  Comcada631e
#
#                                 idUnidad  \
# 73  5a655197-c40a-4b4e-9bdf-67b5137a4be0
# 98  ab048a18-469c-4e4c-85db-993b99856efe
#
#                                                   SQL
# 73  INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(ID...
# 98  INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE(ID...
