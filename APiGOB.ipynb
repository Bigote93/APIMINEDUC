# %% [markdown]
# <a href="https://colab.research.google.com/github/Bigote93/APIMINEDUC/blob/main/APiGOB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apertura de recursos de Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import uuid

# %% [markdown]
# ## Cargar y transformar a excel el json
#
# Para poder almacenar regiones en la base de datos

# %%
import pandas as pd

# Definir la lista de regiones
regiones = [
            {
                'number': 'CHI-1',
                'name': "Región de Arica y Parinacota",
                'comunas': ["Arica", "Camarones", "Putre", "General Lagos"]
            },
            {
                'number': 'CHI-2',
                'name': "Región de Tarapacá",
                'comunas': ["Iquique", "Alto Hospicio", "Pozo Almonte", "Camiña", "Colchane", "Huara", "Pica"],
            },
            {
                'number': 'CHI-3',
                'name': "Región de Antofagasta",
                'comunas': ["Antofagasta", "Mejillones", "Sierra Gorda", "Taltal", "Calama", "Ollagüe", "San Pedro de Atacama", "Tocopilla", "María Elena"],
            },
            {
                'number': 'CHI-4',
                'name': "Región de Atacama",
                'comunas': ["Copiapó", "Caldera", "Tierra Amarilla", "Chañaral", "Diego de Almagro", "Vallenar", "Alto del Carmen", "Freirina", "Huasco"],
            },
            {
                'number': 'CHI-5',
                'name': "Región de Coquimbo",
                'comunas': ["La Serena", "Coquimbo", "Andacollo", "La Higuera", "Paiguano", "Vicuña", "Illapel", "Canela", "Los Vilos", "Salamanca"],
            },
            {
                'number': 'CHI-6',
                'name': "Región de Valparaíso",
                'comunas': ["Valparaíso", "Casablanca", "Concón", "Juan Fernández", "Puchuncaví", "Quintero", "Viña del Mar", "Isla de Pascua", "Los Andes", "Calle Larga", "Rinconada", "San Esteban", "La Ligua", "Cabildo", "Papudo", "Petorca", "Zapallar", "Quillota", "La Calera", "Hijuelas", "La Cruz", "Nogales", "San Antonio", "Algarrobo", "Cartagena", "El Quisco", "El Tabo", "Santo Domingo", "San Felipe", "Catemu", "Llaillay", "Panquehue", "Putaendo", "Santa María", "Quilpué", "Limache", "Olmué"]
            },
            {
                'number': 'CHI-7',
                'name': "Región Metropolitana de Santiago",
                'comunas': ["Santiago", "Cerrillos", "Cerro Navia", "Conchalí", "El Bosque", "Estación Central", "Huechuraba", "Independencia", "La Cisterna", "La Florida", "La Granja", "La Pintana", "La Reina", "Las Condes", "Lo Barnechea", "Lo Espejo", "Lo Prado", "Macul", "Maipú", "Ñuñoa", "Pedro Aguirre Cerda", "Peñalolén", "Providencia", "Pudahuel", "Quilicura", "Quinta Normal", "Recoleta", "Renca", "San Joaquín", "San Miguel", "San Ramón", "Vitacura"]
            },
            {
                'number': 'CHI-8',
                'name': "Región del Libertador General Bernardo O'Higgins",
                'comunas': ["Rancagua", "Codegua", "Coinco", "Coltauco", "Doñihue", "Graneros", "Las Cabras", "Machalí", "Malloa", "Mostazal", "Olivar", "Peumo", "Pichidegua", "Quinta de Tilcoco", "Rengo", "Requínoa", "San Vicente", "Pichilemu", "La Estrella", "Litueche", "Marchihue", "Navidad", "Paredones"]
            },
            {
                'number': 'CHI-9',
                'name': "Región del Maule",
                'comunas': ["Talca", "Constitución", "Curepto", "Empedrado", "Maule", "Pelarco", "Pencahue", "Río Claro", "San Clemente", "San Rafael", "Cauquenes", "Chanco", "Pelluhue", "Curicó", "Hualañé", "Licantén", "Molina", "Rauco", "Romeral", "Sagrada Familia", "Teno", "Vichuquén", "Linares", "Colbún", "Longaví", "Parral", "Retiro", "San Javier", "Villa Alegre", "Yerbas Buenas"]
            },
            {
                'number': 'CHI-10',
                'name': "Región del Maule",
                'comunas': ["Talca", "Constitución", "Curepto", "Empedrado", "Maule", "Pelarco", "Pencahue", "Río Claro", "San Clemente", "San Rafael", "Cauquenes", "Chanco", "Pelluhue", "Curicó", "Hualañé", "Licantén", "Molina", "Rauco", "Romeral", "Sagrada Familia", "Teno", "Vichuquén", "Linares", "Colbún", "Longaví", "Parral", "Retiro", "San Javier", "Villa Alegre", "Yerbas Buenas"]
            },
            {
                'number': 'CHI-11',
                'name': "Región de Ñuble",
                'comunas': ["Chillán", "Chillán Viejo", "Bulnes", "Cobquecura", "Coelemu", "Coihueco", "Chillán Viejo", "El Carmen", "Ninhue", "Ñiquén", "Pemuco", "Pinto", "Portezuelo", "Quillón", "Quirihue", "Ránquil", "San Carlos", "San Fabián", "San Ignacio", "San Nicolás", "Treguaco", "Yungay"]
            },
            {
                'number': 'CHI-12',
                'name': "Región del Biobío",
                'comunas': ["Concepción", "Coronel", "Chiguayante", "Florida", "Hualqui", "Lota", "Penco", "San Pedro de la Paz", "Santa Juana", "Talcahuano", "Tomé", "Hualpén", "Lebu", "Arauco", "Cañete", "Contulmo", "Curanilahue", "Los Álamos", "Tirúa", "Los Ángeles", "Antuco", "Cabrero", "Laja", "Mulchén", "Nacimiento", "Negrete", "Quilaco", "Quilleco", "San Rosendo", "Santa Bárbara", "Tucapel", "Yumbel"]
            },
            {
                'number': 'CHI-13',
                'name': "Región de La Araucanía",
                'comunas': ["Temuco", "Carahue", "Cunco", "Curarrehue", "Freire", "Galvarino", "Gorbea", "Lautaro", "Loncoche", "Melipeuco", "Nueva Imperial", "Padre las Casas", "Perquenco", "Pitrufquén", "Pucón", "Saavedra", "Teodoro Schmidt", "Toltén", "Vilcún", "Villarrica", "Cholchol", "Angol", "Collipulli", "Curacautín", "Ercilla", "Lonquimay", "Los Sauces", "Lumaco", "Purén", "Renaico", "Traiguén", "Victoria"]
            },
            {
                'number': 'CHI-14',
                'name': "Región de Los Ríos",
                'comunas': ["Valdivia", "Corral", "Lanco", "Los Lagos", "Máfil", "Mariquina", "Paillaco", "Panguipulli", "La Unión", "Futrono", "Lago Ranco", "Río Bueno"],
            },
            {
                'number': 'CHI-15',
                'name': "Región de Los Ríos",
                'comunas': ["Valdivia", "Corral", "Lanco", "Los Lagos", "Máfil", "Mariquina", "Paillaco", "Panguipulli", "La Unión", "Futrono", "Lago Ranco", "Río Bueno"],
            },
            {
                'number': 'CHI-16',
                'name': "Región de Los Lagos",
                'comunas': ["Puerto Montt", "Calbuco", "Cochamó", "Fresia", "Frutillar", "Los Muermos", "Llanquihue", "Maullín", "Puerto Varas", "Castro", "Ancud", "Chonchi", "Curaco de Vélez", "Dalcahue", "Puqueldón", "Queilén", "Quellón", "Quemchi", "Quinchao", "Osorno", "Puerto Octay", "Purranque", "Puyehue", "Río Negro", "San Juan de la Costa", "San Pablo", "Chaitén", "Futaleufú", "Hualaihué", "Palena"]
            },
            {
                'number': 'CHI-17',
                'name': "Región de Aysén del General Carlos Ibáñez del Campo",
                'comunas': ["Coyhaique", "Lago Verde", "Aysén", "Cisnes", "Guaitecas", "Cochrane", "O'Higgins", "Tortel", "Chile Chico", "Río Ibáñez"]
            },
            {
                'number': 'CHI-18',
                'name': "Región de Magallanes y de la Antártica Chilena",
                'comunas': ["Punta Arenas", "Laguna Blanca", "Río Verde", "San Gregorio", "Cabo de Hornos", "Antártica", "Porvenir", "Primavera", "Timaukel", "Natales", "Torres del Paine"]
            },
        ]

# Crear un DataFrame de pandas solo con 'number' y 'name'
df = pd.DataFrame({'number': [region['number'] for region in regiones],
                   'name': [region['name'] for region in regiones]})

# Escribir el DataFrame en un archivo Excel
nombre_archivo = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx'
df.to_excel(nombre_archivo, index=False)

print(f"Se ha creado el archivo Excel '{nombre_archivo}' con los datos de las regiones.")
# Out:
# Se ha creado el archivo Excel '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx' con los datos de las regiones.

# %%
#Incorporar columna con la sentencia de insert para postgresql

# Leer el archivo Excel existente
archivo_excel = "/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx"
df = pd.read_excel(archivo_excel)

ID_CHILE = 'f107de1f-5553-4396-9b46-d4df8a1cbfc2'

# Crear una nueva columna con el formato deseado
df['sentencia_sql'] = df.apply(lambda row: f"INSERT INTO testcreates_region (id_region, nombre_region,pais_id) VALUES ('{row['number']}', '{row['name']}', '{ID_CHILE}');", axis=1)

# Guardar el DataFrame actualizado en un nuevo archivo Excel
nuevo_archivo_excel = "/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx"
df.to_excel(nuevo_archivo_excel, index=False)

print(f"Se ha creado el archivo '{nuevo_archivo_excel}' con la columna 'sentencia_sql'.")
# Out:
# Se ha creado el archivo '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/regiones_chile.xlsx' con la columna 'sentencia_sql'.

# %% [markdown]
# ## Carga de objetivos en dataframe

# %%
# Leer el archivo excel de los objetivos de enseñanza basica
objetivos_basica = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/API_OBJ_BASICA.xlsx'

# Lista de objetivos
cursos = [
    'Primero_basico','Segundo_basico','Tercero_basico','Cuarto_basico',
    'Quinto_basico','Sexto_basico','Septimo_basico','Octavo_basico'
    ]

df_columnas = pd.DataFrame(
    columns=['index','idNivel','nombreNivel','descripcionNivel','idAsignatura',
             'nombreAsignatura','idUnidad','nombreUnidad','idObjetivo','descObjetivo'
             ]
    )

# Recorremos las hojas y almacenamos todos los objetivos en un solo dataframe de objetivos basica
for curso in cursos:
  df_objetivos = pd.read_excel(objetivos_basica, sheet_name=curso)
  # Unimos los dataframes en un solo dataframe
  df_columnas = pd.concat([df_columnas,df_objetivos]).reset_index(drop=True)

df_objetivos_basica = df_columnas.drop(columns=['index'])

df_objetivos_basica
# Out:
#         idNivel       nombreNivel             descripcionNivel  \
# 0    STR-NIV-1B  Primero Básico      Estudiantes de 6 a 7 años
# 1    STR-NIV-1B  Primero Básico      Estudiantes de 6 a 7 años
# 2    STR-NIV-1B  Primero Básico      Estudiantes de 6 a 7 años
# 3    STR-NIV-1B  Primero Básico      Estudiantes de 6 a 7 años
# 4    STR-NIV-1B  Primero Básico      Estudiantes de 6 a 7 años
# ..          ...               ...                          ...
# 177   STR-NIV-8     Octavo basico  Estudiantes de 13 a 14 años
# 178   STR-NIV-8     Octavo basico  Estudiantes de 13 a 14 años
# 179   STR-NIV-8     Octavo basico  Estudiantes de 13 a 14 años
# 180   STR-NIV-8     Octavo basico  Estudiantes de 13 a 14 años
# 181   STR-NIV-8     Octavo basico  Estudiantes de 13 a 14 años
#
#        idAsignatura nombreAsignatura          idUnidad  \
# 0    STR-ASIG-MT-1B       Matemática  STR-UNIT-1-MT-1B
# 1    STR-ASIG-MT-1B       Matemática  STR-UNIT-1-MT-1B
# 2    STR-ASIG-MT-1B       Matemática  STR-UNIT-1-MT-1B
# 3    STR-ASIG-MT-1B       Matemática  STR-UNIT-1-MT-1B
# 4    STR-ASIG-MT-1B       Matemática  STR-UNIT-1-MT-1B
# ..              ...              ...               ...
# 177  STR-ASIG-MT-8B       Matemática  STR-UNIT-3-MT-8B
# 178  STR-ASIG-MT-8B       Matemática  STR-UNIT-3-MT-8B
# 179  STR-ASIG-MT-8B       Matemática  STR-UNIT-4-MT-8B
# 180  STR-ASIG-MT-8B       Matemática  STR-UNIT-4-MT-8B
# 181  STR-ASIG-MT-8B       Matemática  STR-UNIT-4-MT-8B
#
#                    nombreUnidad     idObjetivo  \
# 0         Números y Operaciones   STR-OBJ-1-1B
# 1         Números y Operaciones   STR-OBJ-2-1B
# 2         Números y Operaciones   STR-OBJ-3-1B
# 3         Números y Operaciones   STR-OBJ-4-1B
# 4         Números y Operaciones   STR-OBJ-5-1B
# ..                          ...            ...
# 177                   Geometria  STR-OBJ-13-8B
# 178                   Geometria  STR-OBJ-14-8B
# 179  Probabilidad y estadistica  STR-OBJ-15-8B
# 180  Probabilidad y estadistica  STR-OBJ-16-8B
# 181  Probabilidad y estadistica  STR-OBJ-17-8B
#
#                                           descObjetivo
# 0    Contar numeros del 0 al 100 de 1 en 1, de 2 en...
# 1    Identificar el orden de los elementos de una s...
# 2    Leer números del 0 al 20 y representarlos en f...
# 3    Comparar y ordenar números del 0 al 20 de meno...
# 4    Estimar cantidades hasta 20 en situaciones con...
# ..                                                 ...
# 177  Describir la posición y el movimiento (traslac...
# 178  Componer rotaciones, traslaciones y reflexione...
# 179  Mostrar que comprenden las medidas de posición...
# 180  Evaluar la forma en que los datos están presen...
# 181  Explicar el principio combinatorio multiplicat...
#
# [182 rows x 9 columns]

# %%
# Leer el archivo excel de los objetivos de enseñanza basica
objetivos_media = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/API_OBJ_MEDIA.xlsx'
objetivos_insert = '/content/drive/MyDrive/Taller de Desarrollo Soluciones 2/APIS_APP/API_OBJ_MEDIA_inserts.xlsx'

# Lista de objetivos
cursos = ['Primero_medio','Segundo_medio']

df_columnas = pd.DataFrame(
    columns=['index','idNivel','nombreNivel','descripcionNivel','idAsignatura',
             'nombreAsignatura','idUnidad','nombreUnidad','idObjetivo','descObjetivo'
             ]
    )

# Recorremos las hojas y almacenamos todos los objetivos en un solo dataframe de objetivos basica
for curso in cursos:
  df_objetivos = pd.read_excel(objetivos_media, sheet_name=curso)
  # Unimos los dataframes en un solo dataframe
  df_columnas = pd.concat([df_columnas,df_objetivos]).reset_index(drop=True)

# Incorporar la columna de insert en codigo SQL

df_objetivos_media = df_columnas.drop(columns=['index'])

# Crear una nueva columna con el formato deseado
df_objetivos_media['sentencia_sql'] = df_objetivos_media.apply(lambda row: f"INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (id_objetivo_aprendizaje,enunciado_objetivo_aprendizaje,unidad_id) VALUES ('{uuid.uuid4()}','{row['descObjetivo']}', '{row['idUnidad']}');", axis=1)


df_objetivos_media.to_excel(objetivos_insert, sheet_name='Objetivos_insert')

df_objetivos_media['sentencia_sql']
# Out:
# 0     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 1     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 2     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 3     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 4     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 5     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 6     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 7     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 8     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 9     INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 10    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 11    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 12    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 13    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 14    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 15    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 16    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 17    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 18    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 19    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 20    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 21    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 22    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 23    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 24    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 25    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# 26    INSERT INTO TESTCREATES_OBJETIVOAPRENDIZAJE (i...
# Name: sentencia_sql, dtype: object
